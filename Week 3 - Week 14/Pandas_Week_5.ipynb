# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.5.3
# 1.23.5

# %%
# Resampling pada data deret waktu
n_rows = 365 * 24
n_cols = 2
cols= ['col1', 'col2']

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)),
                  columns=cols)
df.index = pd.util.testing.makeDateIndex(n_rows, freq='H')

df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/__init__.py:16: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#                      col1  col2
# 2000-01-01 00:00:00    13    17
# 2000-01-01 01:00:00    18    12
# 2000-01-01 02:00:00    11     8
# 2000-01-01 03:00:00    11    18
# 2000-01-01 04:00:00     1    12
# ...                   ...   ...
# 2000-12-30 19:00:00    11    18
# 2000-12-30 20:00:00    19     1
# 2000-12-30 21:00:00     2    18
# 2000-12-30 22:00:00    15     6
# 2000-12-30 23:00:00     2     2
#
# [8760 rows x 2 columns]

# %%
df.resample('M')['col1'].sum().to_frame()
# Out:
#             col1
# 2000-01-31  7449
# 2000-02-29  7036
# 2000-03-31  7571
# 2000-04-30  7230
# 2000-05-31  7151
# 2000-06-30  7204
# 2000-07-31  7377
# 2000-08-31  7458
# 2000-09-30  7419
# 2000-10-31  7409
# 2000-11-30  7344
# 2000-12-31  7079

# %%
df.resample('D')['col1'].sum().to_frame()
# Out:
#             col1
# 2000-01-01   257
# 2000-01-02   266
# 2000-01-03   212
# 2000-01-04   308
# 2000-01-05   243
# ...          ...
# 2000-12-26   271
# 2000-12-27   206
# 2000-12-28   218
# 2000-12-29   231
# 2000-12-30   214
#
# [365 rows x 1 columns]

# %%
# Membentuk dummy Data Frame
pd.DataFrame({'col1':[1,2,3,4],
             'col2':[5,6,7,7]})
# Out:
#    col1  col2
# 0     1     5
# 1     2     6
# 2     3     7
# 3     4     7

# %%
n_rows = 5
n_cols = 3

arr = np.random.randint(1, 20, size=(n_rows, n_cols))
arr
# Out:
# array([[12, 13,  3],
#        [18, 12, 19],
#        [17,  4, 15],
#        [15,  7, 16],
#        [15, 15, 10]])

# %%
pd.DataFrame (arr, columns=tuple('ABC'))
# Out:
#     A   B   C
# 0  12  13   3
# 1  18  12  19
# 2  17   4  15
# 3  15   7  16
# 4  15  15  10

# %%
pd.util.testing.makeDataFrame().head()
# Out:
#                    A         B         C         D
# LKA0G94yK6  0.653441  1.841397 -0.473637  1.603936
# BCoezEkNsr -0.510071  0.527326  0.023541  0.162149
# ydTVZ9d3AE  0.808257 -0.846594  0.392388 -0.691740
# Iw9BBabdu0 -0.089142  1.093544  0.683411 -0.786227
# 0x4eiDluUi -0.303541  0.202920 -1.475789  0.376362

# %%
pd.util.testing.makeMixedDataFrame().head()
# Out:
#      A    B     C          D
# 0  0.0  0.0  foo1 2009-01-01
# 1  1.0  1.0  foo2 2009-01-02
# 2  2.0  0.0  foo3 2009-01-05
# 3  3.0  1.0  foo4 2009-01-06
# 4  4.0  0.0  foo5 2009-01-07

# %%
pd.util.testing.makeTimeDataFrame().head()
# Out:
#                    A         B         C         D
# 2000-01-03 -1.253449 -0.216388 -0.015072 -0.878728
# 2000-01-04  0.364746  0.417693  0.165415  1.361169
# 2000-01-05 -0.723989 -0.955116 -0.104594  0.406058
# 2000-01-06  0.172568 -0.433633 -0.177282 -0.051520
# 2000-01-07 -1.892913  0.916376  0.723243  0.848182

# %%
pd.util.testing.makeMissingDataframe().head()
# Out:
#                    A         B         C         D
# gaiZ3vV7ME -0.279506 -1.047503  1.212991 -0.683244
# 4kWIcywNGw       NaN  0.574602  0.634065       NaN
# BDYoVxh8C5 -0.070063  0.321458  0.939802       NaN
# tF0goBXoch  0.621808 -0.604563 -1.888691  0.403931
# 2jii0UM1Gk  2.049236 -0.833608       NaN -0.168420

# %%
#  Formatting tampilan Data Frame
n_rows= 5
n_cols = 2
cols = ['omset', 'operasional']

df = pd. DataFrame (np.random.randint (1, 20, size=(n_rows, n_cols)),
                    columns=cols)

df
# Out:
#    omset  operasional
# 0      6            8
# 1     12            8
# 2     15           15
# 3      2           13
# 4      9           12

# %%
df ['omset'] = df ['omset'] * 100_000
df ['operasional'] = df ['operasional'] * 10_000
df
# Out:
#      omset  operasional
# 0   600000        80000
# 1  1200000        80000
# 2  1500000       150000
# 3   200000       130000
# 4   900000       120000

# %%
df.index = pd.util.testing.makeDateIndex (n_rows, freq='D')
df = df.reset_index ()
df = df.rename (columns={'index': 'tanggal'})
df
# Out:
#      tanggal    omset  operasional
# 0 2000-01-01   600000        80000
# 1 2000-01-02  1200000        80000
# 2 2000-01-03  1500000       150000
# 3 2000-01-04   200000       130000
# 4 2000-01-05   900000       120000

# %%
formatku = {'tanggal':'{:%d/%m/%y}',
            'operasional': 'Rp {:.2f}',
            'omset': 'Rp {:.2f} '}
laporan = df.style.format (formatku)
laporan
# Out:
# <style type="text/css">
# </style>
# <table id="T_38c70" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38c70_level0_col0" class="col_heading level0 col0" >tanggal</th>
#       <th id="T_38c70_level0_col1" class="col_heading level0 col1" >omset</th>
#       <th id="T_38c70_level0_col2" class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38c70_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38c70_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_38c70_row0_col1" class="data row0 col1" >Rp 600000.00 </td>
#       <td id="T_38c70_row0_col2" class="data row0 col2" >Rp 80000.00</td>
#     </tr>
#     <tr>
#       <th id="T_38c70_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38c70_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_38c70_row1_col1" class="data row1 col1" >Rp 1200000.00 </td>
#       <td id="T_38c70_row1_col2" class="data row1 col2" >Rp 80000.00</td>
#     </tr>
#     <tr>
#       <th id="T_38c70_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38c70_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_38c70_row2_col1" class="data row2 col1" >Rp 1500000.00 </td>
#       <td id="T_38c70_row2_col2" class="data row2 col2" >Rp 150000.00</td>
#     </tr>
#     <tr>
#       <th id="T_38c70_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_38c70_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_38c70_row3_col1" class="data row3 col1" >Rp 200000.00 </td>
#       <td id="T_38c70_row3_col2" class="data row3 col2" >Rp 130000.00</td>
#     </tr>
#     <tr>
#       <th id="T_38c70_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_38c70_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_38c70_row4_col1" class="data row4 col1" >Rp 900000.00 </td>
#       <td id="T_38c70_row4_col2" class="data row4 col2" >Rp 120000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
type (laporan)
# Out:
# pandas.io.formats.style.Styler

# %%
laporan.hide_index()
# Out:
# <ipython-input-17-f1e1dc65f3f0>:1: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   laporan.hide_index()
# <style type="text/css">
# </style>
# <table id="T_38c70" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_38c70_level0_col0" class="col_heading level0 col0" >tanggal</th>
#       <th id="T_38c70_level0_col1" class="col_heading level0 col1" >omset</th>
#       <th id="T_38c70_level0_col2" class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_38c70_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_38c70_row0_col1" class="data row0 col1" >Rp 600000.00 </td>
#       <td id="T_38c70_row0_col2" class="data row0 col2" >Rp 80000.00</td>
#     </tr>
#     <tr>
#       <td id="T_38c70_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_38c70_row1_col1" class="data row1 col1" >Rp 1200000.00 </td>
#       <td id="T_38c70_row1_col2" class="data row1 col2" >Rp 80000.00</td>
#     </tr>
#     <tr>
#       <td id="T_38c70_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_38c70_row2_col1" class="data row2 col1" >Rp 1500000.00 </td>
#       <td id="T_38c70_row2_col2" class="data row2 col2" >Rp 150000.00</td>
#     </tr>
#     <tr>
#       <td id="T_38c70_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_38c70_row3_col1" class="data row3 col1" >Rp 200000.00 </td>
#       <td id="T_38c70_row3_col2" class="data row3 col2" >Rp 130000.00</td>
#     </tr>
#     <tr>
#       <td id="T_38c70_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_38c70_row4_col1" class="data row4 col1" >Rp 900000.00 </td>
#       <td id="T_38c70_row4_col2" class="data row4 col2" >Rp 120000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
laporan.set_caption ('Data Omset dan Operasional')
# Out:
# <style type="text/css">
# </style>
# <table id="T_38c70" class="dataframe">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th id="T_38c70_level0_col0" class="col_heading level0 col0" >tanggal</th>
#       <th id="T_38c70_level0_col1" class="col_heading level0 col1" >omset</th>
#       <th id="T_38c70_level0_col2" class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_38c70_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_38c70_row0_col1" class="data row0 col1" >Rp 600000.00 </td>
#       <td id="T_38c70_row0_col2" class="data row0 col2" >Rp 80000.00</td>
#     </tr>
#     <tr>
#       <td id="T_38c70_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_38c70_row1_col1" class="data row1 col1" >Rp 1200000.00 </td>
#       <td id="T_38c70_row1_col2" class="data row1 col2" >Rp 80000.00</td>
#     </tr>
#     <tr>
#       <td id="T_38c70_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_38c70_row2_col1" class="data row2 col1" >Rp 1500000.00 </td>
#       <td id="T_38c70_row2_col2" class="data row2 col2" >Rp 150000.00</td>
#     </tr>
#     <tr>
#       <td id="T_38c70_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_38c70_row3_col1" class="data row3 col1" >Rp 200000.00 </td>
#       <td id="T_38c70_row3_col2" class="data row3 col2" >Rp 130000.00</td>
#     </tr>
#     <tr>
#       <td id="T_38c70_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_38c70_row4_col1" class="data row4 col1" >Rp 900000.00 </td>
#       <td id="T_38c70_row4_col2" class="data row4 col2" >Rp 120000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
laporan.highlight_min('omset', color='pink')
laporan.highlight_max('omset', color='lightgreen')

laporan.highlight_min('operasional', color='lightblue')
laporan.highlight_max('operasional', color='grey')
# Out:
# <style type="text/css">
# #T_38c70_row0_col2, #T_38c70_row1_col2 {
#   background-color: lightblue;
# }
# #T_38c70_row2_col1 {
#   background-color: lightgreen;
# }
# #T_38c70_row2_col2 {
#   background-color: grey;
# }
# #T_38c70_row3_col1 {
#   background-color: pink;
# }
# </style>
# <table id="T_38c70" class="dataframe">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th id="T_38c70_level0_col0" class="col_heading level0 col0" >tanggal</th>
#       <th id="T_38c70_level0_col1" class="col_heading level0 col1" >omset</th>
#       <th id="T_38c70_level0_col2" class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_38c70_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_38c70_row0_col1" class="data row0 col1" >Rp 600000.00 </td>
#       <td id="T_38c70_row0_col2" class="data row0 col2" >Rp 80000.00</td>
#     </tr>
#     <tr>
#       <td id="T_38c70_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_38c70_row1_col1" class="data row1 col1" >Rp 1200000.00 </td>
#       <td id="T_38c70_row1_col2" class="data row1 col2" >Rp 80000.00</td>
#     </tr>
#     <tr>
#       <td id="T_38c70_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_38c70_row2_col1" class="data row2 col1" >Rp 1500000.00 </td>
#       <td id="T_38c70_row2_col2" class="data row2 col2" >Rp 150000.00</td>
#     </tr>
#     <tr>
#       <td id="T_38c70_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_38c70_row3_col1" class="data row3 col1" >Rp 200000.00 </td>
#       <td id="T_38c70_row3_col2" class="data row3 col2" >Rp 130000.00</td>
#     </tr>
#     <tr>
#       <td id="T_38c70_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_38c70_row4_col1" class="data row4 col1" >Rp 900000.00 </td>
#       <td id="T_38c70_row4_col2" class="data row4 col2" >Rp 120000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Menggabungkan dua Data Frame secara berdampingan
d1 = {'coll' :[1, 2, 3],
      'co12': [10, 20, 30]}
df1 = pd. DataFrame (d1)
df1
# Out:
#    coll  co12
# 0     1    10
# 1     2    20
# 2     3    30

# %%
d2 = {'co13': [4, 5, 6],
      'co14': [40, 50, 60] }
df2 = pd.DataFrame (d2)
df2
# Out:
#    co13  co14
# 0     4    40
# 1     5    50
# 2     6    60

# %%
df = pd.merge (df1, df2, left_index=True, right_index=True)
df
# Out:
#    coll  co12  co13  co14
# 0     1    10     4    40
# 1     2    20     5    50
# 2     3    30     6    60
